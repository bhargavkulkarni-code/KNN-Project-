# %%
import pandas as pd

# %%
advertising=pd.read_csv('C:\\Users\\bharg\\Desktop\\Bhargav\Advertising.csv')
advertising
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
advertising.duplicated().sum()
# Out:
# 0

# %%
advertising.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %% [markdown]
# # advertising dataset doesnot have null values

# %%
numerical=[fea for fea in advertising.columns if advertising[fea].dtypes!=object]
numerical
# Out:
# ['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales']

# %%
categorical=[fea for fea in advertising.columns if advertising[fea].dtypes==object]
categorical
# Out:
# []

# %%
advertising_numerical=advertising[numerical]
advertising_numerical
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# # advertising dataset doesnot have categorical data

# %%
advertising_numerical['Sales'].max()
# Out:
# 27.0

# %%
x=advertising_numerical.iloc[:,1:4]
w=advertising_numerical['Sales']
bins=[0,5,10,15,20,25,30]
label=['0-5','5-10','10-15','15-20','20-25','25-30']
target=pd.cut(w,bins,labels=label)

# %%
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y=target
y
# Out:
# 0      20-25
# 1      10-15
# 2       5-10
# 3      15-20
# 4      10-15
#        ...
# 195     5-10
# 196     5-10
# 197    10-15
# 198    25-30
# 199    10-15
# Name: Sales, Length: 200, dtype: category
# Categories (6, object): ['0-5' < '5-10' < '10-15' < '15-20' < '20-25' < '25-30']

# %% [markdown]
# # here x is independent and y is dependent variable here bins created for Sales.

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=12)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_prediction=knn.predict(x_test)
y_prediction
# Out:
# array(['10-15', '5-10', '5-10', '10-15', '10-15', '15-20', '25-30',
#        '10-15', '10-15', '10-15', '10-15', '10-15', '5-10', '15-20',
#        '20-25', '10-15', '10-15', '10-15', '10-15', '15-20', '20-25',
#        '5-10', '20-25', '5-10', '15-20', '5-10', '10-15', '10-15', '5-10',
#        '5-10', '10-15', '20-25', '15-20', '20-25', '5-10', '15-20',
#        '10-15', '20-25', '10-15', '5-10', '10-15', '20-25', '5-10',
#        '15-20', '15-20', '10-15', '5-10', '10-15', '10-15', '5-10',
#        '5-10', '10-15', '15-20', '5-10', '10-15', '20-25', '15-20',
#        '10-15', '20-25', '5-10'], dtype=object)

# %%
knn.score(x_test,y_test)
# Out:
# 0.8

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_prediction,digits=3))
# Out:
#               precision    recall  f1-score   support
#
#          0-5      0.000     0.000     0.000         1
#        10-15      0.792     0.905     0.844        21
#        15-20      0.900     0.750     0.818        12
#        20-25      0.778     0.778     0.778         9
#        25-30      0.000     0.000     0.000         2
#         5-10      0.812     0.867     0.839        15
#
#     accuracy                          0.800        60
#    macro avg      0.547     0.550     0.547        60
# weighted avg      0.777     0.800     0.786        60
# C:\Users\bharg\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# # comments:
# 1. precision is accuracy of positive predictions by model.
# 2. recall is maximizing true positives from all actual positive samples of dataset.
# 3. f1 score is harmonic mean of precision and recall.
# 4. accuracy score is 0.8
